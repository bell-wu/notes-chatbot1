# %%
import os
from llama_index.core import SimpleDirectoryReader
# Out:
# /Users/bell/projects/chatbot1/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Files & Loading

# %%
base_folder = "./docs"

reader = SimpleDirectoryReader(base_folder, recursive=True, exclude_hidden=True)

# %%
reader.input_files
# Out:
# [PosixPath('/Users/bell/projects/chatbot1/docs/general_info.txt'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/BOC1___T2___L7.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/ECAL1___T2___L14.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/ECAL1___T2___L2.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/ECAL2___T4___L13.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/FM___T3___L11.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/GE___T2___L9.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/GE___T4___L2.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/GOW___T2___L11.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/GOW___T2___L17.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/raw_notes/GOW___T2___L7.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/BOC1___T2___L7.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/ECAL1___T2___L14.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/ECAL1___T2___L2.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/ECAL2___T4___L13.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/FM___T3___L11.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/GE___T2___L9.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/GE___T4___L2.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L11.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L17.md'),
#  PosixPath('/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md')]

# %%
docs = reader.load_data()

# %%
print(docs[0].get_metadata_str())
# Out:
# file_path: /Users/bell/projects/chatbot1/docs/general_info.txt
# file_name: general_info.txt
# file_type: text/plain
# file_size: 648
# creation_date: 2025-12-19
# last_modified_date: 2025-12-19

# %%
docs[0].__dict__
# Out:
# {'id_': '5afa30a9-1d4a-4486-8f82-cc0949cc0513',
#  'embedding': None,
#  'metadata': {'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt',
#   'file_name': 'general_info.txt',
#   'file_type': 'text/plain',
#   'file_size': 648,
#   'creation_date': '2025-12-19',
#   'last_modified_date': '2025-12-19'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text='FTTA Notes chatbot\n\nThe Full-time Training in Anaheim is a two-year Bible truth and service school located in Anaheim, California. It is referred to as the FTTA or sometimes simply "the training."\n\nThe two-year program is split into four terms (semesters). You can call the students in each term a first termer, second termer, third termer, and fourth termer. In my notes, the four terms are denoted T1, T2, T3, and T4. \n\nSome of the classes and their abbreviations: \nWOG - Word of God\nBOC1 - Body of Christ (1)\nBOC2 - Body of Christ (2)\nECAL1 - Experience of Christ as Life (1)\nECAL2 - Experience of Christ as Life (2)\nFM - Full Ministry of Christ', path=None, url=None, mimetype=None),
#  'image_resource': None,
#  'audio_resource': None,
#  'video_resource': None,
#  'text_template': '{metadata_str}\n\n{content}'}

# %% [markdown]
# # Nodes

# %%
from llama_index.core.node_parser import SentenceSplitter

node_parser = SentenceSplitter(chunk_size=100, chunk_overlap=0)

# %%
nodes = node_parser.get_nodes_from_documents(docs, show_progress=True)
# Out:
# Parsing nodes:   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# # Indexing

# %%
# from langchain_community.vectorstores import Chroma
# from langchain_chroma import Chroma

# %%
# db = Chroma.from_documents(documents, embedding_llm, persist_directory="./chroma",
                          # collection_name="planetbucks")

# %%
# db.persist()

# %%
from llama_index.core import VectorStoreIndex

# %%
import openai
with open('secret/openai_api_key.txt') as f:
    openai_api_key = f.read()

openai.api_key = openai_api_key

# %%
index = VectorStoreIndex(nodes, )
# Out:
# 2025-12-29 12:17:31,560 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:33,388 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:34,410 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:34,823 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:36,813 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:38,295 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:39,017 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:39,991 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:40,657 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:41,032 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:41,696 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:43,116 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:43,894 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:44,755 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:46,702 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:47,314 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:47,928 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:48,746 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:49,157 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:49,917 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-29 12:17:51,119 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
# !rm -rf ./storage

# %%
index_dir = "./storage"
index.storage_context.persist(index_dir)
