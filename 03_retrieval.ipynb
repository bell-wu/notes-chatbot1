# %% [markdown]
# # Load Databases

# %%
import openai
with open('secret/openai_api_key.txt') as f:
    openai_api_key = f.read()

openai.api_key = openai_api_key

# %%
index_dir = "./storage"

from llama_index.core import load_index_from_storage, StorageContext
# Out:
# /Users/bell/projects/chatbot1/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
storage_context = StorageContext.from_defaults(persist_dir=index_dir)

index = load_index_from_storage(storage_context)

# %%
qe = index.as_query_engine()
qe.query("how many terms are in the training?")
# Out:
# Response(response='The training program consists of four terms.', source_nodes=[NodeWithScore(node=TextNode(id_='c8359505-b649-47ba-ac44-45e9c26ef087', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-18', 'last_modified_date': '2025-12-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7a7605af-5b19-4413-b3b3-52f06e66da15', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-18', 'last_modified_date': '2025-12-19
# ...

# %% [markdown]
# ## Retriever

# %%
retriever = index.as_retriever()

query = "how many classes are in the training?"
retriever.retrieve(query)
# Out:
# [NodeWithScore(node=TextNode(id_='c8359505-b649-47ba-ac44-45e9c26ef087', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-18', 'last_modified_date': '2025-12-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7a7605af-5b19-4413-b3b3-52f06e66da15', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-18', 'last_modified_date': '2025-12-19'}, hash='32b4ce0c76ae210c71cba96d2c49deea1d2a8a5712451597d2c5138da93a9b2a'), <
# ...

# %% [markdown]
# # Query Engine

# %%
qe = index.as_query_engine()

# %%
response = qe.query(query).response
print(response)
# Out:
# The training consists of four terms (semesters), each with multiple classes.

# %%
query = "What is the definition of the Lord's table? What are the Bible verse references that support this definition?"
response = qe.query(query).response
print(response)
# Out:
# The Lord's table refers to the enjoyment of the Lord in fellowship. This concept is supported by the idea that it signifies man's enjoyment for God, while the Lord's supper is for the Lord's enjoyment. The Bible verse references that support this definition are not provided in the context.
