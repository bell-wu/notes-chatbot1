# %% [markdown]
# # Load Databases

# %%
import openai
with open('secret/openai_api_key.txt') as f:
    openai_api_key = f.read()

openai.api_key = openai_api_key

# %%
index_dir = "./storage"

from llama_index.core import load_index_from_storage, StorageContext
# Out:
# /Users/bell/projects/chatbot1/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
storage_context = StorageContext.from_defaults(persist_dir=index_dir)

index = load_index_from_storage(storage_context)

# %%
qe = index.as_query_engine()
qe.query("how many terms are in the training?")
# Out:
# Response(response='The training program is split into four terms (semesters).', source_nodes=[NodeWithScore(node=TextNode(id_='b24913a5-8baa-45f5-b79d-b417701e8560', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-19', 'last_modified_date': '2025-12-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5afa30a9-1d4a-4486-8f82-cc0949cc0513', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-19', 'last_modified_date': '2025-12-19'}, hash='a6f65137726668b6a4a80a36ce20f5ec222135a0f2d74a21ea3b4cbaf5d8898d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='12528208-100c-4d00-a0b5-1c56bf3fd3ce', node_type='1', metadata={}, hash='6dce505b0dcbbe2919471c502341bf3cb8cadcf3b4f58922977424833562d13f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='FTTA Notes chatbot\n\nThe Full-time Training in Anaheim is a two-year Bible truth and service school located in Anaheim, California. It is referred to as the FTTA or sometimes simply "the training."\n\nThe two-year program is split into four terms (semesters). You can call the students in each term a first termer, second termer, third termer, and fourth termer.', mimetype='text/plain', start_char_idx=0, end_char_idx=359, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.800545494043572), NodeWithScore(node=TextNode(id_='6e6f56e3-2675-450f-9e27-38863027ac0e', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='389c58c9-fe09-4964-a53d-f6583121c13b', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, hash='7fedc3248073cf586a20f514fcfbdc868e35e68a6053e1a9ba55450fa35c48bc'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ead7be82-8240-4e03-870d-04e742464a4c', node_type='1', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, hash='7682c53728fe9eda77f7f882a070e8df4d7d21383d9ab61678c242a58840c825'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='91c447ef-4e54-4dce-937f-4143c33a974a', node_type='1', metadata={}, hash='07ffaf9b9086cbf904d99fa93ea37554511585907ec2daf32eb512e6a73a0ec6')}, metadata_template='{key}: {value}', metadata_separator='\n', text="**\n\t\t- I remember brother Andrew Yu said, when the trainees go back, there are two possibilities: one is, they don't practice what they learned. That's not good, of course. The other type is they faithfully practice what they heard. That's good, but not good enough.", mimetype='text/plain', start_char_idx=23895, end_char_idx=24161, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7866208374471502)], metadata={'b24913a5-8baa-45f5-b79d-b417701e8560': {'file_path' ...

# %% [markdown]
# ## Retriever

# %%
retriever = index.as_retriever()

query = "how many classes are in the training?"
retriever.retrieve(query)
# Out:
# [NodeWithScore(node=TextNode(id_='b8ac4af2-a761-4b49-9a67-238af26a3b17', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='389c58c9-fe09-4964-a53d-f6583121c13b', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, hash='7fedc3248073cf586a20f514fcfbdc868e35e68a6053e1a9ba55450fa35c48bc'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='52a06005-7ab2-4dde-a456-208e54cc3c1f', node_type='1', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/ref_notes/GOW___T2___L7.md', 'file_name': 'GOW___T2___L7.md', 'file_size': 24431, 'creation_date': '2025-12-29', 'last_modified_date': '2025-12-29'}, hash='ac55dfb090606ebe6aa815fa25f6c0e550291b297b41b9f5c4546e4832d24163'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='ec8874e1-c2b8-4de5-8dbc-fb886ca49f13', node_type='1', metadata={}, hash='36b963bea06d8e292fca7b1dfca5614a2859741b09feab2a5ce87c5f58e45bdb')}, metadata_template='{key}: {value}', metadata_separator='\n', text='- And so we visited a certain denomination, and they had through their larger national association, had a program for education. They had Sunday school. Every Lord Jesus morning, there would be time for a Sunday school class for men and Sunday school class for ladies.', mimetype='text/plain', start_char_idx=1606, end_char_idx=1874, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7742814770137452),
#  NodeWithScore(node=TextNode(id_='b24913a5-8baa-45f5-b79d-b417701e8560', embedding=None, metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-19', 'last_modified_date': '2025-12-19'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5afa30a9-1d4a-4486-8f82-cc0949cc0513', node_type='4', metadata={'file_path': '/Users/bell/projects/chatbot1/docs/general_info.txt', 'file_name': 'general_info.txt', 'file_type': 'text/plain', 'file_size': 648, 'creation_date': '2025-12-19', 'last_modified_date': '2025-12-19'}, hash='a6f65137726668b6a4a80a36ce20f5ec222135a0f2d74a21ea3b4cbaf5d8898d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='12528208-100c-4d00-a0b5-1c56bf3fd3ce', node_type='1', metadata={}, hash='6dce505b0dcbbe2919471c502341bf3cb8cadcf3b4f58922977424833562d13f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='FTTA Notes chatbot\n\nThe Full-time Training in Anaheim is a two-year Bible truth and service school located in Anaheim, California. It is referred to as the FTTA or sometimes simply "the training."\n\nThe two-year program is split into four terms (semesters). You can call the students in each term a first termer, second termer, third termer, and fourth termer.', mimetype='text/plain', start_char_idx=0, end_char_idx=359, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7726366804961029)]

# %% [markdown]
# # Query Engine

# %%
qe = index.as_query_engine()

# %%
response = qe.query(query).response
print(response)
# Out:
# There are two classes in the training.

# %%
query = "What is the definition of the Lord's table? What are the Bible verse references that support this definition?"
response = qe.query(query).response
print(response)
# Out:
# The Lord's table refers to the enjoyment of the Lord in fellowship. This enjoyment involves joint participation and fellowship with Him for our satisfaction. The Bible verse references that support this definition are related to the practice of partaking in the Lord's Supper and the remembrance of Him.
